# %% [markdown]
# Data Analysis with Python

# %% [markdown]
# Objectives
# After completing this project I will be able to:
#
# Explore features or charecteristics to predict price of car

# %% [markdown]
# Table of Contents:
# Import Data from Module,
# Analyzing Individual Feature Patterns using Visualization,
# Descriptive Statistical Analysis,
# Basics of Grouping,
# Correlation and Causation,
# ANOVA,

# %% [markdown]
# What are the main characteristics that have the most impact on the car price?

# %% [markdown]
# 1. Import Data from Module 2

# %% [markdown]
# Import libraries:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Load the data and store it in dataframe df:
#
# This dataset was hosted on IBM Cloud object.

# %%
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# 2. Analyzing Individual Feature Patterns Using Visualization

# %% [markdown]
# To install Seaborn I use pip, the Python package manager.
#
# Import visualization packages "Matplotlib" and "Seaborn". Don't forget about "%matplotlib inline" to plot in a Jupyter notebook.

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Choose the right visualization method by type of variable

# %%
## list the data types for each column
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
#Data type of individual coloumn
df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# For example, I can calculate the correlation between variables of type "int64" or "float64" using the method "corr":

# %%
df.corr(numeric_only=True)
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# Continuous Numerical Variables:

# %% [markdown]
# Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.
#
# In order to start understanding the (linear) relationship between an individual variable and the price, I can use "regplot" which plots the scatterplot plus the fitted regression line for the data. This will be useful later on for visualizing the fit of the simple linear regression model as well.

# %% [markdown]
# Let's see several examples of different linear relationships:

# %% [markdown]
# Positive Linear Relationship

# %% [markdown]
# Let's find the scatterplot of "engine-size" and "price".

# %%
# Engine size as potential predictor variable of price
sns.regplot(x='engine-size', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 53504.817141910105)

# %% [markdown]
# As the engine-size goes up, the price goes up: this indicates a positive direct correlation between these two variables. Engine size seems like a pretty good predictor of price since the regression line is almost a perfect diagonal line.
#
# I can examine the correlation between 'engine-size' and 'price' and see that it's approximately 0.87.

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# Highway mpg is a potential predictor variable of price. Let's find the scatterplot of "highway-mpg" and "price".

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %% [markdown]
# As highway-mpg goes up, the price goes down: this indicates an inverse/negative relationship between these two variables. Highway mpg could potentially be a predictor of price.

# %% [markdown]
# I can examine the correlation between 'highway-mpg' and 'price' and see it's approximately -0.704.

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# Weak Linear Relationship

# %% [markdown]
# Let's see if "peak-rpm" is a predictor variable of "price".

# %%
sns.regplot(x='peak-rpm',y='price',data=df)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %% [markdown]
# Peak rpm does not seem like a good predictor of the price at all since the regression line is close to horizontal. Also, the data points are very scattered and far from the fitted line, showing lots of variability. Therefore, it's not a reliable variable.

# %% [markdown]
# I can examine the correlation between 'peak-rpm' and 'price' and see it's approximately -0.101616.

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
# Let's see if "stroke" is a predictor variable of "price".

# %%
df[['stroke','price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.regplot(x='stroke',y='price',data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %% [markdown]
# Stroke does not seem like a good predictor of the price at all since the regression line is close to horizontal. Also, the data points are very scattered and far from the fitted line, showing lots of variability. Therefore, it's not a reliable variable.

# %% [markdown]
# Categorical Variables
# These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.

# %% [markdown]
# Let's look at the relationship between "body-style" and "price".

# %%
sns.boxplot(x="body-style",y='price',data=df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %% [markdown]
# I see that the distributions of price between the different body-style categories have a significant overlap, so body-style would not be a good predictor of price. Let's examine engine "engine-location" and "price":

# %%
sns.boxplot(x='engine-location',y='price',data=df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %% [markdown]
# Here we see that the distribution of price between these two engine-location categories, front and rear, are distinct enough to take engine-location as a potential good predictor of price.

# %% [markdown]
# Let's examine "drive-wheels" and "price".

# %%
sns.boxplot(x='drive-wheels',y='price',data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# Here I see that the distribution of price between the different drive-wheels categories differs. As such, drive-wheels could potentially be a predictor of price.

# %% [markdown]
# 3. Descriptive Statistical Analysis

# %% [markdown]
# Let's first take a look at the variables by utilizing a description method.

# %% [markdown]
# The describe function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.

# %% [markdown]
# I can apply the method "describe" as follows:

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %% [markdown]
# The default setting of "describe" skips variables of type object. I can apply the method "describe" on the variables of type 'object' as follows:

# %%
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %% [markdown]
# Value Counts

# %% [markdown]
# Value counts is a good way of understanding how many units of each characteristic/variable I have. I can apply the "value_counts" method on the column "drive-wheels".

# %%
df['drive-wheels'].value_counts()
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %% [markdown]
# We can convert the series to a dataframe as follows:

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %% [markdown]
# Let's repeat the above steps but save the results to the dataframe "drive_wheels_counts" and rename the column 'drive-wheels' to 'value_counts'.

# %%
drive_wheels_counts=df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'},inplace=True)
drive_wheels_counts
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %% [markdown]
# Now let's rename the index to 'drive-wheels':

# %%
drive_wheels_counts.index.name=('drive-wheels')
drive_wheels_counts
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %% [markdown]
# I can repeat the above process for the variable 'engine-location'.

# %%
# engine-location as variable
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  count
# engine-location
# front              198
# rear                 3

# %% [markdown]
# After examining the value counts of the engine location, I see that engine location would not be a good predictor variable for the price. This is because I only have three cars with a rear engine and 198 with an engine in the front, so this result is skewed. Thus, I are not able to draw any conclusions about the engine location.

# %% [markdown]
# 4. Basics of Grouping

# %% [markdown]
# The "groupby" method groups data by different categories. The data is grouped based on one or several variables, and analysis is performed on the individual groups.
#
# For example, let's group by the variable "drive-wheels". I see that there are 3 different categories of drive wheels.

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %% [markdown]
# If I want to know, on average, which type of drive wheel is most valuable, I can group "drive-wheels" and then average them.
#
# I can select the columns 'drive-wheels', 'body-style' and 'price', then assign it to the variable "df_group_one".

# %%
df_group_one=df[['drive-wheels','body-style','price']]

# %% [markdown]
# I can then calculate the average price for each of the different categories of data.

# %%
# grouping results
df_group_one=df_group_one.groupby(['drive-wheels'],as_index=False).mean(numeric_only=True)
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# From our data, it seems rear-wheel drive vehicles are, on average, the most expensive, while 4-wheel and front-wheel are approximately the same in price.
#
# Let's group by both 'drive-wheels' and 'body-style'.

# %%
# grouping results
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# This grouped data is much easier to visualize when it is made into a pivot table.
# In this case, I will leave the drive-wheels variable as the rows of the table, and pivot body-style to become the columns of the table:

# %%
grouped_pivot=grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# Often, I won't have data for some of the pivot cells. We can fill these missing cells with the value 0

# %%
#fill missing values with 0
grouped_pivot=grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# Let's group by the variable "body-style"

# %%
df_gptest1 = df[['body-style','price']]
grouped_test2 = df_gptest.groupby(['body-style'],as_index=False).mean(numeric_only=True)
grouped_test2
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %% [markdown]
# Variables: Drive Wheels and Body Style vs. Price

# %% [markdown]
# Let's use a heat map to visualize the relationship between Body Style vs Price.

# %%
#use the grouped results
plt.pcolor(grouped_pivot,cmap='RdBu')
plt.colorbar()
plt.show()

# %% [markdown]
# The heatmap plots the target variable (price) proportional to colour with respect to the variables 'drive-wheel' and 'body-style' on the vertical and horizontal axis, respectively. This allows us to visualize how the price is related to 'drive-wheel' and 'body-style'.

# %% [markdown]
# The default labels convey no useful information to us. Let's change that:

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %% [markdown]
# 5. Correlation and Causation

# %% [markdown]
# Correlation: a measure of the extent of interdependence between variables.
# Causation: the relationship between cause and effect between two variables.

# %% [markdown]
# Pearson Correlation
# The Pearson Correlation measures the linear dependence between two variables X and Y.

# %%
df.corr(numeric_only=True)
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# P-value
#
# The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, I choose a significance level of 0.05, which means that I are 95% confident that the correlation between the variables is significant.
#
# By convention, when the
# p-value is < 0.001: I say there is strong evidence that the correlation is significant.
# the p-value is < 0.05: there is moderate evidence that the correlation is significant.
# the p-value is < 0.1: there is weak evidence that the correlation is significant.
# the p-value is > 0.1: there is no evidence that the correlation is significant.

# %% [markdown]
# I can obtain this information using "stats" module in the "scipy" library.

# %%
from scipy import stats

# %% [markdown]
# Wheel-Base vs. Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'wheel-base' and 'price'.

# %%
pearson_coef, p_value=stats.pearsonr(df['wheel-base'],df['price'])
print('The pearson correlation coefficient is',pearson_coef,'With a p-value of p=',p_value)
# Out:
# The pearson correlation coefficient is 0.584641822265508 With a p-value of p= 8.076488270732847e-20

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between wheel-base and price is statistically significant, although the linear relationship isn't extremely strong (~0.585).

# %% [markdown]
# Length vs. Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'length' and 'price'.

# %%
pearson_coef, p_value=stats.pearsonr(df['length'],df['price'])
print('The pearson correlation coefficient is',pearson_coef,'With a p-value of p=',p_value)
# Out:
# The pearson correlation coefficient is 0.6906283804483639 With a p-value of p= 8.016477466159293e-30

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between length and price is statistically significant, and the linear relationship is moderately strong (~0.691).

# %% [markdown]
# Width vs. Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'width' and 'price':

# %%
pearson_coef, p_value=stats.pearsonr(df['width'],df['price'])
print('The pearson correlation coefficient is',pearson_coef,'With a p-value of p=',p_value)
# Out:
# The pearson correlation coefficient is 0.7512653440522675 With a p-value of p= 9.200335510480586e-38

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is quite strong (~0.751).

# %% [markdown]
# Curb-Weight vs. Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'curb-weight' and 'price':

# %%
pearson_coef, p_value=stats.pearsonr(df['curb-weight'],df['price'])
print('The pearson correlation coefficient is',pearson_coef,'With a p-value of p=',p_value)
# Out:
# The pearson correlation coefficient is 0.8344145257702844 With a p-value of p= 2.189577238893924e-53

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between curb-weight and price is statistically significant, and the linear relationship is quite strong (~0.834).

# %% [markdown]
# Engine-Size vs. Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'engine-size' and 'price':

# %%
pearson_coef, p_value=stats.pearsonr(df['engine-size'],df['price'])
print('The pearson correlation coefficient is',pearson_coef,'With a p-value of p=',p_value)
# Out:
# The pearson correlation coefficient is 0.8723351674455184 With a p-value of p= 9.26549162219869e-64

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between engine-size and price is statistically significant, and the linear relationship is very strong (~0.872).

# %% [markdown]
# Bore vs. Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'bore' and 'price':

# %%
pearson_coef, p_value=stats.pearsonr(df['bore'],df['price'])
print('The pearson correlation coefficient is',pearson_coef,'With a p-value of p=',p_value)
# Out:
# The pearson correlation coefficient is 0.5431553832626603 With a p-value of p= 8.049189483935274e-17

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between bore and price is statistically significant, but the linear relationship is only moderate (~0.521).

# %% [markdown]
# I can relate the process for each 'city-mpg' and 'highway-mpg':
#
# City-mpg vs. Price

# %%
pearson_coef, p_value=stats.pearsonr(df['city-mpg'],df['price'])
print('The pearson correlation coefficient is',pearson_coef,'With a p-value of p=',p_value)
# Out:
# The pearson correlation coefficient is -0.686571006784468 With a p-value of p= 2.3211320655675065e-29

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between city-mpg and price is statistically significant, and the coefficient of about -0.687 shows that the relationship is negative and moderately strong.

# %% [markdown]
# Highway-mpg vs. Price

# %%
pearson_coef, p_value=stats.pearsonr(df['highway-mpg'],df['price'])
print('The pearson correlation coefficient is',pearson_coef,'With a p-value of p=',p_value)
# Out:
# The pearson correlation coefficient is -0.7046922650589531 With a p-value of p= 1.749547114447559e-31

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between highway-mpg and price is statistically significant, and the coefficient of about -0.705 shows that the relationship is negative and moderately strong.

# %% [markdown]
# ANOVA: Analysis of Variance

# %% [markdown]
# If my price variable is strongly correlated with the variable we are analyzing, I expect ANOVA to return a sizeable F-test score and a small p-value.

# %% [markdown]
# Drive Wheels

# %% [markdown]
# Since ANOVA analyzes the difference between different groups of the same variable, the groupby function will come in handy.
# To see if different types of 'drive-wheels' impact 'price', we group the data.

# %%
grouped_test2=df_gptest[['drive-wheels','price']].groupby(['drive-wheels'])
grouped_test2.head()
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 2            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 6            fwd  17710.0
# 7            fwd  18920.0
# 8            fwd  23875.0
# 9            rwd  16430.0
# 10           rwd  16925.0
# 136          4wd   7603.0
# 140          4wd   9233.0
# 141          4wd  11259.0
# 144          4wd   8013.0

# %%
df_gptest
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
grouped_test2.get_group('4wd')['price']
# Out:
# C:\Users\RIAZ\AppData\Local\Temp\ipykernel_14232\4164424613.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   grouped_test2.get_group('4wd')['price']
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %% [markdown]
# We can use the function 'f_oneway' in the module 'stats' to obtain the F-test score and P-value.

# %%
# ANOVA
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.954065007804 , P = 3.3945443577149576e-23
# C:\Users\RIAZ\AppData\Local\Temp\ipykernel_14232\4111350723.py:2: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])

# %% [markdown]
# This is a great result with a large F-test score showing a strong correlation and a P-value of almost 0 implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated?
#
# Let's examine them separately.

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'],grouped_test2.get_group('rwd')['price'])
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.55331609591107 , P = 2.2355306355677366e-23
# C:\Users\RIAZ\AppData\Local\Temp\ipykernel_14232\1760462407.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'],grouped_test2.get_group('rwd')['price'])

# %% [markdown]
# Let's examine the other groups.

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'],grouped_test2.get_group('rwd')['price'])
print( 'ANOVA results: F=', f_val, ', p =', p_val )
# Out:
# ANOVA results: F= 8.580681368924756 , p = 0.004411492211225367
# C:\Users\RIAZ\AppData\Local\Temp\ipykernel_14232\1122122389.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'],grouped_test2.get_group('rwd')['price'])

# %% [markdown]
# 4wd and fwd

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'],grouped_test2.get_group('fwd')['price'])
print( 'ANOVA results: F=', f_val, ', p =', p_val )
# Out:
# ANOVA results: F= 0.665465750252303 , p = 0.4162011669784502
# C:\Users\RIAZ\AppData\Local\Temp\ipykernel_14232\827003106.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'],grouped_test2.get_group('fwd')['price'])

# %% [markdown]
# We notice that ANOVA for the categories 4wd and fwd yields a high p-value > 0.1, so the calculated F-test score is not very statistically significant. This suggests we can't reject the assumption that the means of these two groups are the same, or, in other words, I can't conclude the difference in correlation to be significant.

# %% [markdown]
# Conclusion: Important Variables

# %% [markdown]
# I now have a better idea of what our data looks like and which variables are important to take into account when predicting the car price. I have narrowed it down to the following variables:
#
# Continuous numerical variables:
#
# Length,
# Width,
# Curb-weight,
# Engine-size,
# Horsepower,
# City-mpg,
# Highway-mpg,
# Wheel-base,
# Bore.
#
# Categorical variables:
# Drive-wheels.
